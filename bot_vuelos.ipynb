# %%
# Integrante: Milton Peralta

from nlp_parser import parse_user_message

mensaje = "Comprar tres billetes para el 15 de octubre con Iberia de Quito a Madrid"
json_intermedio = parse_user_message(mensaje)

print("Mensaje:", mensaje)
print("JSON intermedio:", json_intermedio)
# Out:
# Mensaje: Comprar tres billetes para el 15 de octubre con Iberia de Quito a Madrid
# JSON intermedio: {'origen': 'Quito', 'destino': 'Madrid', 'fecha': '15 de octubre', 'cantidad': '3', 'aerolínea': 'Iberia', 'origen_iso': None, 'destino_iso': None}

# %%
# Integrante: Mishelle Menéndez
from iata_service import build_final_json

json_final = build_final_json(json_intermedio)
print("JSON final:", json_final)
# Out:
# JSON final: {'Ciudad Origen': 'Quito', 'Ciudad Destino': 'Madrid', 'IATA From': 'UIO', 'IATA To': 'MAD', 'Fecha': '15-10-2026', 'Pax': 3, 'Aerolínea': 'Iberia'}

# %%
# Integrante: Anthony Vega
from assistant_bot import asistent

logs = asistent("Nombre_empresa")
print("Historial:", logs)
# Out:
# Hola, bienvenido a Nombre_empresa. ¿Como te puedo ayudar?
# >  Quiero 2 billetes de Madrid a Frankfurt en Septiembre
# No pude detectar la AEROLÍNEA. Ej: '... con Iberia' o '... Lufthansa'
# Corrige el mensaje y vuelve a intentarlo. (No se generó JSON final)
# >  Quiero 2 billetes de Madrid a Frankfurt en Septiembre con Lufthansa
# Perfecto, Comienzo la búsqueda de tu viaje a Fráncfort del Meno desde Madrid para el 01-09-2026 con Lufthansa.
#
# JSON final:
# {'Ciudad Origen': 'Madrid', 'Ciudad Destino': 'Fráncfort del Meno', 'IATA From': 'MAD', 'IATA To': 'FRA', 'Fecha': '01-09-2026', 'Pax': 2, 'Aerolínea': 'Lufthansa'}
#
# Escribe otra solicitud o 'salir' para terminar.
# >  Necesito comprar un billete a Madrid el 5 de Agosto
# No pude detectar el ORIGEN. Ej: 'de Quito a Madrid ...'
# No pude detectar la AEROLÍNEA. Ej: '... con Iberia' o '... Lufthansa'
# Corrige el mensaje y vuelve a intentarlo. (No se generó JSON final)
# >  Necesito comprar un billete de Quito a Madrid el 5 de Agosto en Avianca
# Perfecto, Comienzo la búsqueda de tu viaje a Madrid desde Quito para el 05-08-2026 con Avianca.
#
# JSON final:
# {'Ciudad Origen': 'Quito', 'Ciudad Destino': 'Madrid', 'IATA From': 'UIO', 'IATA To': 'MAD', 'Fecha': '05-08-2026', 'Pax': 1, 'Aerolínea': 'Avianca'}
#
# Escribe otra solicitud o 'salir' para terminar.
# >  Comprar billete Barcelona a Roma para el 25 de Agosto con Iberia
# Perfecto, Comienzo la búsqueda de tu viaje a Roma desde Barcelona para el 25-08-2026 con Iberia.
#
# JSON final:
# {'Ciudad Origen': 'Barcelona', 'Ciudad Destino': 'Roma', 'IATA From': 'BCN', 'IATA To': 'ROM', 'Fecha': '25-08-2026', 'Pax': 1, 'Aerolínea': 'Iberia'}
#
# Escribe otra solicitud o 'salir' para terminar.
# >  Billete barato AirEuropa de Madrid a Sevilla
# No pude detectar la FECHA. Ej: '... para el 15 de octubre' o '... en septiembre'
# Corrige el mensaje y vuelve a intentarlo. (No se generó JSON final)
# >  4 billetes barato en diciembre con AirEuropa de Madrid a Sevilla
# Perfecto, Comienzo la búsqueda de tu viaje a Sevilla desde Madrid para el 01-12-2026 con Aireuropa.
#
# JSON final:
# {'Ciudad Origen': 'Madrid', 'Ciudad Destino': 'Sevilla', 'IATA From': 'MAD', 'IATA To': 'SVQ', 'Fecha': '01-12-2026', 'Pax': 4, 'Aerolínea': 'Aireuropa'}
#
# Escribe otra solicitud o 'salir' para terminar.
# >  salir
# ¡Listo! Conversación finalizada.
# Historial: [{'Ciudad Origen': 'Madrid', 'Ciudad Destino': 'Fráncfort del Meno', 'IATA From': 'MAD', 'IATA To': 'FRA', 'Fecha': '01-09-2026', 'Pax': 2, 'Aerolínea': 'Lufthansa'}, {'Ciudad Origen': 'Quito', 'Ciudad Destino': 'Madrid', 'IATA From': 'UIO', 'IATA To': 'MAD', 'Fecha': '05-08-2026', 'Pax': 1, 'Aerolínea': 'Avianca'}, {'Ciudad Origen': 'Barcelona', 'Ciudad Destino': 'Roma', 'IATA From': 'BCN', 'IATA To': 'ROM', 'Fecha': '25-08-2026', 'Pax': 1, 'Aerolínea': 'Iberia'}, {'Ciudad Origen': 'Madrid', 'Ciudad Destino': 'Sevilla', 'IATA From': 'MAD', 'IATA To': 'SVQ', 'Fecha': '01-12-2026', 'Pax': 4, 'Aerolínea': 'Aireuropa'}]

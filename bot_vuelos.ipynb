# %%
# Integrante: Milton Peralta

from nlp_parser import parse_user_message

mensaje = "Comprar tres billetes para el 15 de octubre con Iberia de Quito a Madrid"
json_intermedio = parse_user_message(mensaje)

print("Mensaje:", mensaje)
print("JSON intermedio:", json_intermedio)
# Out:
# Mensaje: Comprar tres billetes para el 15 de octubre con Iberia de Quito a Madrid
# JSON intermedio: {'origen': 'Quito', 'destino': 'Madrid', 'fecha': '15 de octubre', 'cantidad': '3', 'aerolínea': 'Iberia'}

# %%
# Integrante: Mishelle Menéndez
from iata_service import build_final_json

json_final = build_final_json(json_intermedio)
print("JSON final:", json_final)
# Out:
# JSON final: {'Ciudad Origen': 'Quito', 'Ciudad Destino': 'Madrid', 'IATA From': 'UIO', 'IATA To': 'MAD', 'Fecha': '15-10-2026', 'Pax': 3}

# %%
# Integrante: Anthony Vega
from assistant_bot import asistent

logs = asistent("Nombre_empresa")
print("Historial:", logs)
# Out:
# Hola, bienvenido a Nombre_empresa. ¿Como te puedo ayudar?
# >  Comprar tres billetes para el 15 de octubre con Iberia de Quito a Madrid
# Perfecto: Quito (UIO) -> Madrid (MAD), Fecha: 15-10-2026, Pax: 3.
#
# JSON final:
# {'Ciudad Origen': 'Quito', 'Ciudad Destino': 'Madrid', 'IATA From': 'UIO', 'IATA To': 'MAD', 'Fecha': '15-10-2026', 'Pax': 3}
#
# Escribe otra solicitud o 'salir' para terminar.
# >  Comprar dos billetes para el 5 de noviembre con Avianca de Guayaquil a Rio de Janeiro
# Perfecto: Guayaquil (GYE) -> Rio De Janeiro (RIO), Fecha: 05-11-2026, Pax: 2.
#
# JSON final:
# {'Ciudad Origen': 'Guayaquil', 'Ciudad Destino': 'Rio De Janeiro', 'IATA From': 'GYE', 'IATA To': 'RIO', 'Fecha': '05-11-2026', 'Pax': 2}
#
# Escribe otra solicitud o 'salir' para terminar.
# >  Comprar cuatro billetes para el 20 de diciembre con LATAM de Cuenca a Bogota
# Perfecto: Cuenca (CUE) -> Bogota (BOG), Fecha: 20-12-2026, Pax: 4.
#
# JSON final:
# {'Ciudad Origen': 'Cuenca', 'Ciudad Destino': 'Bogota', 'IATA From': 'CUE', 'IATA To': 'BOG', 'Fecha': '20-12-2026', 'Pax': 4}
#
# Escribe otra solicitud o 'salir' para terminar.
# >  Comprar un billete para el 3 de enero con KLM de Quito a Amsterdam
# Perfecto: Quito (UIO) -> Amsterdam (AMS), Fecha: 03-01-2026, Pax: 1.
#
# JSON final:
# {'Ciudad Origen': 'Quito', 'Ciudad Destino': 'Amsterdam', 'IATA From': 'UIO', 'IATA To': 'AMS', 'Fecha': '03-01-2026', 'Pax': 1}
#
# Escribe otra solicitud o 'salir' para terminar.
# >  salir
# ¡Listo! Conversación finalizada.
# Historial: [{'Ciudad Origen': 'Quito', 'Ciudad Destino': 'Madrid', 'IATA From': 'UIO', 'IATA To': 'MAD', 'Fecha': '15-10-2026', 'Pax': 3}, {'Ciudad Origen': 'Guayaquil', 'Ciudad Destino': 'Rio De Janeiro', 'IATA From': 'GYE', 'IATA To': 'RIO', 'Fecha': '05-11-2026', 'Pax': 2}, {'Ciudad Origen': 'Cuenca', 'Ciudad Destino': 'Bogota', 'IATA From': 'CUE', 'IATA To': 'BOG', 'Fecha': '20-12-2026', 'Pax': 4}, {'Ciudad Origen': 'Quito', 'Ciudad Destino': 'Amsterdam', 'IATA From': 'UIO', 'IATA To': 'AMS', 'Fecha': '03-01-2026', 'Pax': 1}]

# %%
# Integrante: Milton Peralta

# BLOQUE 1 - EXTRACCIÓN NLP
# Responsable: Integrante 1

from nlp_parser import parse_user_message

mensaje = "Comprar tres billetes para el 15 de octubre con Iberia de Quito a Madrid"

json_intermedio = parse_user_message(mensaje)

print("Mensaje de entrada:")
print(mensaje)

print("\nJSON intermedio (extracción):")
print(json_intermedio)
# Out:
# Mensaje de entrada:
# Comprar tres billetes para el 15 de octubre con Iberia de Quito a Madrid
#
# JSON intermedio (extracción):
# {'origen': 'Quito', 'destino': 'Madrid', 'fecha': '15 de octubre', 'cantidad': '3', 'aerolínea': 'Iberia'}

# %%
# Integrante: Mishelle Menéndez

# BLOQUE 2 - POST-PROCESO Y VALIDACIÓN
# Responsable: Integrante 2

from iata_service import postprocess_entities

json_final = postprocess_entities(json_intermedio)

print("JSON final (validado y normalizado):")
print(json_final)
# Out:
# JSON final (validado y normalizado):
# {'origen': 'Quito', 'destino': 'Madrid', 'fecha': '15 de octubre', 'cantidad': '3', 'aerolínea': 'Iberia'}

# %%
# Integrante: Anthony Vega

# BLOQUE 3 - ASISTENTE VIRTUAL
# Responsable: Integrante 3

from assistant_bot import asistent

logs = asistent("Nombre_empresa")

print("\nHistorial de mensajes procesados:")
print(logs)
# Out:
# Hola, bienvenido a Nombre_empresa. ¿Como te puedo ayudar?
# >  Comprar tres billetes para el 15 de octubre con Iberia de Quito a Madrid
# Perfecto, Comienzo la búsqueda de tu viaje a Madrid desde Quito para el 15 de octubre con Iberia.
#
# JSON:
# {'origen': 'Quito', 'destino': 'Madrid', 'fecha': '15 de octubre', 'cantidad': '3', 'aerolínea': 'Iberia'}
#
# Escribe otra solicitud o 'salir' para terminar.
# >  salir
# ¡Listo! Conversación finalizada.
#
# Historial de mensajes procesados:
# [{'origen': 'Quito', 'destino': 'Madrid', 'fecha': '15 de octubre', 'cantidad': '3', 'aerolínea': 'Iberia'}]
